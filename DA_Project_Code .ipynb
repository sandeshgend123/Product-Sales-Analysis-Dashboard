# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl as xls

# %%
d = pd.read_excel("C:\\Users\\sande\\OneDrive\\Desktop\\DA project.xlsx")
df = pd.DataFrame(d)

# %%
df
# Out:
#            Retailer  Retailer ID Invoice Date  Month  Year     Region  \
# 0           Walmart      1128299    2020-04-03   Apr  2020  Southeast
# 1         West Gear      1128299    2020-12-26   Dec  2020      South
# 2     Sports Direct      1197831    2020-02-18   Feb  2020      South
# 3     Sports Direct      1197831    2021-03-28   Mar  2021      South
# 4     Sports Direct      1197831    2021-02-16   Feb  2021      South
# ...             ...          ...           ...   ...   ...        ...
# 4994         Amazon      1185732    2021-02-20   Feb  2021  Northeast
# 4995         Amazon      1185732    2020-08-04   Aug  2020  Northeast
# 4996      West Gear      1185732    2021-06-04   Jun  2021  Northeast
# 4997      West Gear      1185732    2020-04-26   Apr  2020  Northeast
# 4998         Amazon      1185732    2020-01-24   Jan  2020  Northeast
#
#           State         City                    Product  Price per Unit  \
# ...

# %%
df.isnull().sum()
# Out:
# Retailer            0
# Retailer ID         0
# Invoice Date        2
# Month               0
# Year                0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Sales Method        0
# dtype: int64

# %%
data = df.fillna(method='ffill')
data
# Out:
# C:\Users\sande\AppData\Local\Temp\ipykernel_10000\2343735486.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = df.fillna(method='ffill')
#            Retailer  Retailer ID Invoice Date  Month  Year     Region  \
# 0           Walmart      1128299    2020-04-03   Apr  2020  Southeast
# 1         West Gear      1128299    2020-12-26   Dec  2020      South
# 2     Sports Direct      1197831    2020-02-18   Feb  2020      South
# 3     Sports Direct      1197831    2021-03-28   Mar  2021      South
# 4     Sports Direct      1197831    2021-02-16   Feb  2021      South
# ...             ...          ...           ...   ...   ...        ...
# 4994         Amazon      1185732    2021-02-20   Feb  2021  Northeast
# 4995         Amazon      1185732    2020-08-04   Aug  2020  Northeast
# 4996      West Gear      1185732    2021-06-04   Jun  2021  Northeast
# ...

# %%
data.isnull().sum()
# Out:
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Month               0
# Year                0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Sales Method        0
# dtype: int64

# %%
data.to_excel("C:\\Users\\sande\\OneDrive\\Desktop\\DA_project.xlsx")
